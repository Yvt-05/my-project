# %%
#Q1 solution
name = input("Enter your name : ")
className = input("Enter your class :")

physics = int(input("Enter your physics marks : "))
chemistry = int(input("Enter your chemistry marks : "))
mathematics = int(input("Enter your mathematics marks : "))
english = int(input("Enter your english marks : "))
physicalEd = int(input("Enter your physical education marks : "))

totalmarks = physics+chemistry+mathematics+english+physicalEd
percentage = float((totalmarks/500)*100)

print(f"name : {name}\nclass : {className}\ntotal marks : {totalmarks}\npercentage : {percentage:.2f}%")
# Out:
# name : YASH VARDHAN TIWARI
# class : 12
# total marks : 440
# percentage : 88.00%

# %%
#Q2 solution
str1 = input("Enter the first string : ")
str2 = input("Enter the second string : ")
str3 = str1+str2
print(f"orignal concatinated string : {str3}")
#operations performed
print(str3.lower())
print(str3.upper())
print(str3.title())
print(str3.swapcase())
print(str3.capitalize())
print(str3.casefold())
print(str3.center(40, "-"))
print(str3.count("is"))
print(str3.endswith("!"))
print(str3.find("fun"))
print(str3.isalnum())
print(str3.isdigit())
print(str3.isnumeric())
print(str3.isspace())
print(str3.replace("fun", "awesome"))
# Out:
# orignal concatinated string : python is easy to workpyhton is easy
# python is easy to workpyhton is easy
# PYTHON IS EASY TO WORKPYHTON IS EASY
# Python Is Easy To Workpyhton Is Easy
# PYTHON IS EASY TO WORKPYHTON IS EASY
# Python is easy to workpyhton is easy
# python is easy to workpyhton is easy
# --python is easy to workpyhton is easy--
# 2
# False
# -1
# False
# False
# False
# False
# python is easy to workpyhton is easy

# %%
#Q3 solution

#shopping cart system

#start with empty cart
cart_total = 0

#user add shoe of value $50
cart_total += 50

#user add t-shirt of value $20
cart_total += 20

#user apply discount of value $5
cart_total -= 5

#user doubles cart 
cart_total *= 2

#user split the bill with friend
cart_total /= 2

#shop drops the decimal as a discount
cart_total //= 1

print(f"final cart value : {cart_total}")
# Out:
# final cart value : 65.0

# %%
#Q1 solution
name = input("Enter your name : ")
className = input("Enter your class :")

physics = int(input("Enter your physics marks : "))
chemistry = int(input("Enter your chemistry marks : "))
mathematics = int(input("Enter your mathematics marks : "))
english = int(input("Enter your english marks : "))
physicalEd = int(input("Enter your physical education marks : "))

totalmarks = physics+chemistry+mathematics+english+physicalEd
percentage = float((totalmarks/500)*100)

if(percentage >= 60):
    grade = "A"
elif(percentage >= 50 and percentage < 60):
    grade = "B"
elif(percentage >= 40 and percentage < 50):
    grade = "C"
elif(percentage >= 33 and percentage < 40):
    grade = "D"
else:
    grade = "Fail"
    

print(f"name : {name}\nclass : {className}\ntotal marks : {totalmarks}\npercentage : {percentage:.2f}%\ngrade : {grade}")
# Out:
# name : Yash
# class : 10
# total marks : 463
# percentage : 92.60%
# grade : A
