# %%
print("Hello", "World", 123)
print("Python", "Java", "C++", sep="-")
print("Hello", end=" ")
print("World")
# Out:
# Hello World 123
# Python-Java-C++
# Hello World

# %%
name = input("Enter your name: ")

print("Hello", name)
# Out:
# Hello yash
